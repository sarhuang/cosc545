# %%
# for each dataset
#YourTopic,
#dataset title,
#dataset license,
#dataset description,
#url(s) were the data may be retrieved
#search engine (see above or another)
#search string/prompt used

#20 different links basically
#still list it even if i get no results from an engine

import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac23mp2']
coll = db ['shuang24']

#coll.delete_one({"url": ""}) - how to delete bad inputs

coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Debian Bug report logs', 'license': 'GNU Public License version 2', 'description': 'Debian Bug report logs: Bugs in package perl (version 5.36.0-9) in unstable', 'engine': 'google.com', 'query': 'perl bug fix dataset', 'url': ['https://bugs.debian.org/cgi-bin/pkgreport.cgi?pkg=perl;dist=unstable'] } )

# %%
#Rest of the Google and Chat GPT engine entries
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Resolved bugs for Data-Util', 'license': 'GNU General Public License, Version 1', 'description': 'This module provides utility functions for data and data types, including functions for subroutines and symbol table hashes (stashes).', 'engine': 'google.com', 'query': 'perl bug fix dataset', 'url': ['https://rt-cpan.github.io/Public/Dist/Data-Util/Resolved/'] } )
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Resolved bugs for Data-Dumper', 'license': 'perl_5', 'description': 'Perl core module Data::Dumper', 'engine': 'google.com', 'query': 'cpan bug dataset', 'url': ['https://rt.cpan.org/Public/Dist/Display.html?Status=Resolved;Name=Data-Dumper'] } )
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'No Perl Datasets in Google SCholar', 'license': 'NA', 'description': 'Google Scholar articles do not contain Perl datasets', 'engine': 'scholar.google.com', 'query': 'perl bug dataset', 'url': ['NA'] } )
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'No Perl Datasets in Google Dataset Search', 'license': 'NA', 'description': 'Google Dataset Search articles do not contain Perl datasets', 'engine': 'datasetsearch.research.google.com', 'query': ['Perl bug fix', 'Perl code fix', 'Perl bug'], 'url': ['NA'] } )
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'No Perl Datasets in Chat GPT', 'license': 'NA', 'description': 'Chat GPT cannot recommend Perl datasets', 'engine': 'Chat GPT', 'query': ['perl software bug fix datasets'], 'url': ['NA'] } )

# %%
#All GitHub engine entries 
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'reading from DATA on win32 with perlio behaves oddly', 'license': 'NA', 'description': 'This is a bug report for perl from mjcarman@​mchsi.com, generated with the help of perlbug 1.34 running under perl v5.8.3.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/7207'] } )    
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Segfault because of uninitialized data in AV ', 'license': 'NA', 'description': 'A bug in av.c:Perl_av_extend_guts() which may cause the underlying array of an AV to have uninitialized (non zeroed) data', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/21235'] } )        
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'state \@array = do {}; runs multiple times.', 'license': 'NA', 'description': 'If a state variable is a declared reference, the initialization code is run more than once.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/19927'] } )                      
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'When @INC contains a blessed object, modifying %INC may modify @INC', 'license': 'NA', 'description': 'This causes further hijinks and hilarity when the rest of the code no longer can be loaded via the @INC hook.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/20577'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'eval foo in package DB called from lexical sub can not see closure values or globals', 'license': 'NA', 'description': 'only the lexicals in the innermost sub are visible; globals and lexicals in enclosing scopes can no longer be accessed.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/19370'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Producing a default value from a do/try/catch block combination fails', 'license': 'NA', 'description': 'Even when following the exact code from the 5.34 perlsyn docs regarding producing a default value with a try/catch block wrapped in a "do" block, the code fails to produce the value.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/18855'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'a1325b902d breaks build on OpenBSD', 'license': 'NA', 'description': 'After a recent commit we have begun to experience build and test failures on OpenBSD.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/18536'] } )             
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'corelist --diff fails with "Cant use an undefined value as a HASH reference" for fake versions', 'license': 'NA', 'description': 'corelist --diff fails for fake perl core versions as command line arguments', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/17792'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'SvPVbyte croaks before handling get magic', 'license': 'NA', 'description': 'This is a bug report for perl from Niko Tyni <ntyni@​debian.org> generated with the help of perlbug 1.39 running under perl 5.11.4.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/10116'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'close and dup hang in threads', 'license': 'NA', 'description': 'This is a bug report for perl from patrik.h.hagglund@​ericsson.com, generated with the help of perlbug 1.39 running under perl 5.14.2.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/11805'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Wrong line number in signature errors', 'license': 'NA', 'description': 'Signature errors are shown with the line number of the subroutine definition. They should show the line number of the actual subroutine call', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/13643'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'SEGV on wraparound', 'license': 'NA', 'description': 'This is caused by integer wraparound on a UV to I32 conversion', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/14490'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'IO::Select cant remove closed socket [rt.cpan.org #77740]', 'license': 'NA', 'description': 'If an IO::Socket handle is closed before removing it from the IO::Select object, IO::Select is unable to remove it.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/17447'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Possible sprintf problem in perl5.8.0', 'license': 'NA', 'description': 'After compiling and installing perl 5.8.0 without any problems I have encountered some weird behaviour with sprintf.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/6225'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'make test breaks permissions on /dev/tty', 'license': 'NA', 'description': 'This obviously breaks a unix system pretty badly.', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/6938'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Problem with system() on Win9x/ME (perl 5.8.0 - 5.9.1)', 'license': 'NA', 'description': 'After installing ActivePerl 5.8.3 build 809 all of these scripts fail. ', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/7229'] } )                            
coll.insert_one ( { 'owner':'shuang24', 'topic':'Perl bug fix', 'title': 'Devel::Peek misprints \a\t\n\f\r in UTF8 strings', 'license': 'NA', 'description': 'Slashes are missing in the output of Devel​::Peek​:', 'engine': 'Github', 'query': 'closed perl issues with bug label', 'url': ['https://github.com/Perl/perl5/issues/9615'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac23mp2']
coll = db ['shuang24']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find({'owner':'shuang24'}):
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('651ee3c7b7a3eabcffe787c7'),
#  'description': 'Debian Bug report logs: Bugs in package perl '
#                 '(version 5.36.0-9) in unstable',
#  'engine': 'google.com',
#  'license': 'GNU Public License version 2',
#  'owner': 'shuang24',
#  'query': 'perl bug fix dataset',
#  'title': 'Debian Bug report logs',
#  'topic': 'Perl bug fix',
#  'url': ['https://bugs.debian.org/cgi-bin/pkgreport.cgi?pkg=perl;dist=unstable']}
# {'_id': ObjectId('651eee97b7a3eabcffe787cd'),
#  'description': 'This module provides utility functions for '
#                 'data and data types, including functions for '
#                 'subroutines and symbol table hashes (stashes).',
#  'engine': 'google.com',
#  'license': 'GNU General Public License, Version 1',
#  'owner': 'shuang24',
#  'query': 'perl bug fix dataset',
#  'title': 'Resolved bugs for Data-Util',
#  'topic': 'Perl bug fix',
#  'url': ['https://rt-cpan.github.io/Public/Dist/Data-Util/Resolved/']}
# ...
